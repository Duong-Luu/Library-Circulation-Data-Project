# %%
import pandas as pd

# %%
smcl_data = pd.read_csv("SMCL_ANF_Items.csv")
# Out:
# C:\Users\onlyd\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
#Renamed the columns for column V, W, X

smcl_data2 = smcl_data.rename(columns={'245|a': 'Book Title','100|a': 'Author',
                                      '008 Date One': 'Published Date'})

#dropped columns

smcl_data_clean = smcl_data2.drop(['LOCATION', 'BARCODE', 'RECORD #(ITEM)',
                 'I TYPE', 'MAT TYPE', 'OTHER CALL', 'MATERIAL'], axis=1)

#created dictionary for the BRANCH column and replaced with actual location

branch_dict = {'0k': 'Bookmobile', '1a':'Atherton', '1b':'Belmont', '1r':'Brisbane','1e':'East Palo Alto','1f':'Foster City'
,'1h':'Half Moon Bay','1m':'Millbrae','1p':'Pacifica Sharp Park','1z':'Pacifica Sanchez','1s':'San Carlos','1v':'Portola Valley','1w':'Woodside'}

#looking for values to combine in Call # field
smcl_data_clean["CALL #"].value_counts()

#cleaning up and only using initial categorey 
smcl_data_clean["CALL #"] = smcl_data_clean["CALL #"].str.split(" ", 1, expand=True)

smcl_data_clean = smcl_data_clean.replace({"BRANCH": branch_dict})

# %%
#looking for values to combine in Call # field
smcl_data_clean["CALL #"].value_counts()

#cleaning up and only using initial categorey 
smcl_data_clean["CALL #"] = smcl_data_clean["CALL #"].str.split(" ", 1, expand=True)
smcl_data_clean.head()
# Out:
#              BRANCH   CREATED(ITEM) RECORD #(BIBLIO) CREATED(BIBLIO)  YTDCIRC  \
# 0    Portola Valley  7/18/2005 8:45        b10000203  7/18/2005 8:45        0
# 1  Pacifica Sanchez  7/18/2005 8:45        b10000276  7/18/2005 8:45        0
# 2       Foster City  7/18/2005 8:45        b1000032x  7/18/2005 8:45        2
# 3          Millbrae  7/18/2005 8:45        b1000032x  7/18/2005 8:45        0
# 4    East Palo Alto  7/18/2005 8:47        b10002364  7/18/2005 8:47        0
#
#    LYRCIRC  TOT CHKOUT  TOT RENEW  # RENEWALS STATUS  DUE DATE  \
# 0        0          15          6           0    m      -  -
# 1        0          30         11           0    -      -  -
# 2        3          40         23           0    -      -  -
# 3        0          17          9           0    -      -  -
# 4        0           8          8           0    m      -  -
#
#            LOUTDATE           LCHKIN   CALL #  \
# 0   4/28/2016 15:35  5/24/2016 11:00   NATURE
# 1   4/18/2018 17:17  5/14/2018 10:40   NATURE
# 2  11/24/2019 16:41  1/10/2020 10:47   NATURE
# 3   7/12/2018 15:36  7/14/2018 11:13   NATURE
# 4    6/8/2016 16:57  8/17/2016 17:01  COOKING
#
#                         Book Title            Author Published Date
# 0        Encyclopedia of mammals /               NaN           1998
# 1         Encyclopedia of fishes /               NaN           1998
# 2          Encyclopedia of birds /               NaN           1998
# 3          Encyclopedia of birds /               NaN           1998
# 4  Caribbean and African cooking /  Grant, Rosamund.           1998

# %%
#Removing items starting with "F-"
smcl_data_removed1 = smcl_data_clean[~smcl_data_clean["CALL #"].astype(str).str.startswith('F-')]
#Removing items starting with "M-"
smcl_data_removed2 = smcl_data_removed1[~smcl_data_removed1["CALL #"].astype(str).str.startswith('M-')]
#Removing items starting with "SF-"
smcl_data_removed3 = smcl_data_removed2[~smcl_data_removed2["CALL #"].astype(str).str.startswith('SF-')]
#Removing items starting with "YA-"
smcl_data_removed4 = smcl_data_removed3[~smcl_data_removed3["CALL #"].astype(str).str.startswith('YA-')]

#Removing items that appear less than 10 times
smcl_data_removed5 = smcl_data_removed4.groupby('CALL #').filter(lambda d: len(d) > 10)

#Removing items that are incorrectly placed into ANF
smcl_data_removed6 = smcl_data_removed5[smcl_data_removed5["CALL #"] != "USB"]
smcl_data_removed7 = smcl_data_removed6[smcl_data_removed6["CALL #"] != "SP"]
smcl_data_removed8 = smcl_data_removed7[smcl_data_removed7["CALL #"] != "CHI"]
smcl_data_removed9 = smcl_data_removed8[smcl_data_removed8["CALL #"] != "J"]
smcl_data_removed10 = smcl_data_removed9[smcl_data_removed9["CALL #"] != "DVD"]
smcl_data_removed11 = smcl_data_removed10[smcl_data_removed10["CALL #"] != "CD"]

# %%
#Combining Call # that are the same
smcl_data_removed_final = smcl_data_removed11.replace({
                                                        "SOC": "SOC SCI",
                                                        "PERS": "PERS FIN", "PER": "PERS FIN",
                                                        "SPORTS": "SPORT",
                                                        "LANG": "LANG INST",
                                                        "CRAFTS": "CRAFT",
                                                        "PETS": "PET",
                                                        "SELF": "SELFHELP",
                                                        "LITERATUR": "LIT",
                                                        "PHILOSOPH": "PHILSOPH",
                                                        })

smcl_data_removed_final.head()
# Out:
#              BRANCH   CREATED(ITEM) RECORD #(BIBLIO) CREATED(BIBLIO)  YTDCIRC  \
# 0    Portola Valley  7/18/2005 8:45        b10000203  7/18/2005 8:45        0
# 1  Pacifica Sanchez  7/18/2005 8:45        b10000276  7/18/2005 8:45        0
# 2       Foster City  7/18/2005 8:45        b1000032x  7/18/2005 8:45        2
# 3          Millbrae  7/18/2005 8:45        b1000032x  7/18/2005 8:45        0
# 4    East Palo Alto  7/18/2005 8:47        b10002364  7/18/2005 8:47        0
#
#    LYRCIRC  TOT CHKOUT  TOT RENEW  # RENEWALS STATUS  DUE DATE  \
# 0        0          15          6           0    m      -  -
# 1        0          30         11           0    -      -  -
# 2        3          40         23           0    -      -  -
# 3        0          17          9           0    -      -  -
# 4        0           8          8           0    m      -  -
#
#            LOUTDATE           LCHKIN   CALL #  \
# 0   4/28/2016 15:35  5/24/2016 11:00   NATURE
# 1   4/18/2018 17:17  5/14/2018 10:40   NATURE
# 2  11/24/2019 16:41  1/10/2020 10:47   NATURE
# 3   7/12/2018 15:36  7/14/2018 11:13   NATURE
# 4    6/8/2016 16:57  8/17/2016 17:01  COOKING
#
#                         Book Title            Author Published Date
# 0        Encyclopedia of mammals /               NaN           1998
# 1         Encyclopedia of fishes /               NaN           1998
# 2          Encyclopedia of birds /               NaN           1998
# 3          Encyclopedia of birds /               NaN           1998
# 4  Caribbean and African cooking /  Grant, Rosamund.           1998

# %%
smcl_data_removed_final['Total_cir'] = smcl_data_removed_final['TOT CHKOUT'] + smcl_data_removed_final['TOT RENEW']
smcl_data_removed_final.head()
# Out:
#              BRANCH   CREATED(ITEM) RECORD #(BIBLIO) CREATED(BIBLIO)  YTDCIRC  \
# 0    Portola Valley  7/18/2005 8:45        b10000203  7/18/2005 8:45        0
# 1  Pacifica Sanchez  7/18/2005 8:45        b10000276  7/18/2005 8:45        0
# 2       Foster City  7/18/2005 8:45        b1000032x  7/18/2005 8:45        2
# 3          Millbrae  7/18/2005 8:45        b1000032x  7/18/2005 8:45        0
# 4    East Palo Alto  7/18/2005 8:47        b10002364  7/18/2005 8:47        0
#
#    LYRCIRC  TOT CHKOUT  TOT RENEW  # RENEWALS STATUS  DUE DATE  \
# 0        0          15          6           0    m      -  -
# 1        0          30         11           0    -      -  -
# 2        3          40         23           0    -      -  -
# 3        0          17          9           0    -      -  -
# 4        0           8          8           0    m      -  -
#
#            LOUTDATE           LCHKIN   CALL #  \
# 0   4/28/2016 15:35  5/24/2016 11:00   NATURE
# 1   4/18/2018 17:17  5/14/2018 10:40   NATURE
# 2  11/24/2019 16:41  1/10/2020 10:47   NATURE
# 3   7/12/2018 15:36  7/14/2018 11:13   NATURE
# 4    6/8/2016 16:57  8/17/2016 17:01  COOKING
#
#                         Book Title            Author Published Date  Total_cir
# 0        Encyclopedia of mammals /               NaN           1998         21
# 1         Encyclopedia of fishes /               NaN           1998         41
# 2          Encyclopedia of birds /               NaN           1998         63
# 3          Encyclopedia of birds /               NaN           1998         26
# 4  Caribbean and African cooking /  Grant, Rosamund.           1998         16

# %%
smcl_data_removed_final_groupby = smcl_data_removed_final.groupby(['BRANCH', 'CALL #'])
smcl_grouped = smcl_data_removed_final_groupby.sum()

# %%
smcl_grouped
# Out:
#                    YTDCIRC  LYRCIRC  TOT CHKOUT  TOT RENEW  # RENEWALS  \
# BRANCH   CALL #
# Atherton ART             6        9          58         71           1
#          BIO           246      537        2498       1659         139
#          BUSINESS       65      132         835       1144          46
#          COLLECT         2        0           8         15           3
#          COMPUTE        23       51         232        560          30
# ...                    ...      ...         ...        ...         ...
# Woodside SPORT          20       41         475        427           7
#          TECH            1        3          22         32           5
#          TRANSPRT        0        2          32         31           0
#          TRAVEL        219      333        2041       1983          37
#          TRIBE           1        2          75         45           0
#
#                    Total_cir
# BRANCH   CALL #
# Atherton ART             129
#          BIO            4157
#          BUSINESS       1979
#          COLLECT          23
#          COMPUTE         792
# ...                      ...
# Woodside SPORT           902
#          TECH             54
#          TRANSPRT         63
#          TRAVEL         4024
#          TRIBE           120
#
# [470 rows x 6 columns]

# %%
smcl_grouped_new = smcl_grouped.drop(['YTDCIRC', 'YTDCIRC', 'TOT CHKOUT', 'TOT RENEW', '# RENEWALS', 'LYRCIRC'], axis=1)
#.sort_values(by='Total_cir', ascending=False)

# %%
smcl_grouped_new
# Out:
#                    Total_cir
# BRANCH   CALL #
# Atherton ART             129
#          BIO            4157
#          BUSINESS       1979
#          COLLECT          23
#          COMPUTE         792
# ...                      ...
# Woodside SPORT           902
#          TECH             54
#          TRANSPRT         63
#          TRAVEL         4024
#          TRIBE           120
#
# [470 rows x 1 columns]

# %%
print(smcl_grouped_new.to_string())
# Out:
#                                Total_cir
# BRANCH              CALL #
# Atherton            ART              129
#                     BIO             4157
#                     BUSINESS        1979
#                     COLLECT           23
#                     COMPUTE          792
#                     COOKING         3540
#                     CRAFT           1170
#                     EDUCATE         1108
#                     GAME             118
#                     GARDEN          1817
#                     HEALTH          3124
#                     HISTORY         2039
#                     HOLIDAY           23
#                     HOME            1923
#                     LANG INST         84
#                     LAW              419
#                     LIFE            1074
#                     LIT              573
#                     MYTH/FLK          43
#                     NATURE           298
#                     PARTY             22
#                     PERS FIN        1011
#                     PET              361
#                     PHILSOPH         203
#                     PSYCH            901
#                     RELIGION         762
#                     SCIENCE          828
#                     SELFHELP        2495
#                     SOC SCI         1258
#                     SPIRIT          1141
#                     SPORT             83
#                     TECH              35
#                     TRAVEL          3237
# Belmont             ART            15292
#                     BIO            14965
#                     BUSINESS       20161
#                     COLLECT          304
#                     COMPUTE        10810
#                     CONSUMER         114
#                     COOKING        39812
#                     CRAFT          16255
#                     EDUCATE        13868
#                     FARMING          647
#                     GAME            1307
#                     GARDEN          9562
#                     GENEALGY         107
#                     HEALTH         22668
#                     HISTORY        18916
#                     HOBBY            173
#                     HOLIDAY         1225
#                     HOME           18732
#                     LANG INST       4215
#                     LAW             2886
#                     LIFE           17575
#                     LIT            12650
#                     MYTH/FLK         363
#                     NATURE          4844
#                     PARTY           1212
#                     PERS FIN        8323
#                     PET             3047
#                     PHILSOPH        2749
#                     PSYCH           8587
#                     RELIGION        9682
#                     SCIENCE         7929
#                     SELFHELP       14982
#                     SOC SCI         7391
#                     SPIRIT          4709
#                     SPORT           7410
#                     TECH            1624
#                     TRANSPRT         735
#                     TRAVEL         22911
#                     TRIBE            154
# Bookmobile          ART               76
#                     BIO               58
#                     BUSINESS          43
#                     COOKING          128
#                     CRAFT              1
#                     EDUCATE            0
#                     GARDEN            18
#                     HEALTH            38
#                     HISTORY            9
#                     LAW               17
#                     LIFE              17
#                     PSYCH             20
#                     SELFHELP           8
#                     SOC SCI           28
#                     TRAVEL            40
# Brisbane            ART             1377
#                     BIO             2132
#                     BUSINESS        1618
#                     COLLECT           50
#                     COMPUTE          928
#                     CONSUMER          87
#                     COOKING         3899
#                     CRAFT            580
#                     EDUCATE         1250
#                     FARMING           31
#                     GAME             225
#                     GARDEN          1356
#                     HEALTH          2513
#                     HISTORY         2505
#                     HOLIDAY          185
#                     HOME            2054
#                     LANG INST        173
#                     LAW              443
#                     LIFE            1603
#                     LIT             1430
#                     MYTH/FLK          72
#                     NATURE           866
#                     PARTY            107
#                     PERS FIN         651
#                     PET              202
#                     PHILSOPH         296
#                     PSYCH            417
#                     RELIGION         796
#                     SCIENCE          742
#                     SELFHELP        1904
#                     SOC SCI         1298
#                     SPIRIT           619
#                     SPORT            686
#                     TECH              58
#                     TRANSPRT          82
#                     TRAVEL          1945
#                     TRIBE             38
# East Palo Alto      ART              905
#                     BIO             2181
#                     BUSINESS        1176
#                     COLLECT           12
#                     COMPUTE          148
#                     CONSUMER           0
#                     COOKING         1899
#                     CRAFT            951
#                     EDUCATE         1483
#                     FARMING           44
#                     GAME             128
#                     GARDEN           860
#                     GENEALGY          32
#                     HEALTH          1553
#                     HISTORY          763
#                     HOBBY             56
#                     HOLIDAY          132
#                     HOME             494
#                     LANG INST        536
#                     LAW              652
#                     LIFE            1263
#                     LIT              912
#                     MYTH/FLK          46
#                     NATURE           315
#                     PARTY              8
#                     PERS FIN        1232
#                     PET               69
#                     PHILSOPH         284
#                     PSYCH            636
#                     RELIGION         560
#                     SCIENCE          592
#                     SELFHELP        1340
#                     SOC SCI         1461
#                     SPIRIT           415
#                     SPORT            333
#                     TECH             176
#                     TRANSPRT         195
#                     TRAVEL           761
#                     TRIBE              0
# Foster City         ART            32583
#                     BIO            29794
#                     BUSINESS       34720
#                     COLLECT          318
#                     COMPUTE        17109
#                     CONSUMER         321
#                     COOKING        44025
#                     CRAFT          17684
#                     EDUCATE        23739
#                     FARMING          596
#                     GAME            3139
#                     GARDEN         12520
#                     GENEALGY         177
#                     HEALTH         32920
#                     HISTORY        26987
#                     HOBBY            323
#                     HOLIDAY         1379
#                     HOME           14877
#                     LANG INST       7205
#                     LAW             5780
#                     LIFE           20582
#                     LIT            11555
#                     MYTH/FLK         920
#                     NATURE          4431
#                     PARTY            957
#                     PERS FIN       17429
#                     PET             2977
#                     PHILSOPH        4649
#                     PSYCH          11082
#                     RELIGION        9868
#                     SCIENCE        15292
#                     SELFHELP       24660
#                     SOC SCI        17680
#                     SPIRIT          5919
#                     SPORT           8298
#                     TECH            3801
#                     TRANSPRT        1036
#                     TRAVEL         14816
#                     TRIBE            326
# Half Moon Bay       ART             5995
#                     BIO             8420
#                     BUSINESS        4149
#                     COLLECT          181
#                     COMPUTE         1174
#                     CONSUMER           0
#                     COOKING        10857
#                     CRAFT           4062
#                     EDUCATE         1578
#                     FARMING          511
#                     GAME             538
#                     GARDEN          2937
#                     HEALTH          7530
#                     HISTORY         6035
#                     HOBBY            170
#                     HOLIDAY          376
#                     HOME            3095
#                     LANG INST        972
#                     LAW             1198
#                     LIFE            3523
#                     LIT             3100
#                     MYTH/FLK         306
#                     NATURE          2279
#                     PARTY            180
#                     PERS FIN        2678
#                     PET             1296
#                     PHILSOPH         702
#                     PSYCH           1707
#                     RELIGION        1518
#                     SCIENCE         3016
#                     SELFHELP        4383
#                     SOC SCI         2573
#                     SPIRIT          1929
#                     SPORT           1818
#                     TECH             601
#                     TRANSPRT         419
#                     TRAVEL          4860
#                     TRIBE            322
# Millbrae            ART            18517
#                     BIO            17876
#                     BUSINESS       14014
#                     COLLECT          462
#                     COMPUTE         4836
#                     CONSUMER           0
#                     COOKING        38001
#                     CRAFT           9550
#                     EDUCATE         9313
#                     FARMING          362
#                     GAME            2071
#                     GARDEN          9214
#                     GENEALGY         171
#                     HEALTH         15873
#                     HISTORY        17797
#                     HOBBY            147
#                     HOLIDAY         1263
#                     HOME           16287
#                     LANG INST       3995
#                     LAW             3030
#                     LIFE            9641
#                     LIT             8017
#                     MYTH/FLK         544
#                     NATURE          2837
#                     PARTY           1049
#                     PERS FIN        9278
#                     PET             2189
#                     PHILSOPH        2012
#                     PSYCH           5863
#                     RELIGION        8174
#                     SCIENCE         4890
#                     SELFHELP        9754
#                     SOC SCI         8814
#                     SPIRIT          3651
#                     SPORT           6738
#                     TECH            1906
#                     TRANSPRT        1142
#                     TRAVEL         10525
#                     TRIBE            306
# Pacifica Sanchez    ART             5867
#                     BIO             7363
#                     BUSINESS        2234
#                     COLLECT          162
#                     COMPUTE         1588
#                     CONSUMER          43
#                     COOKING        14096
#                     CRAFT           4894
#                     EDUCATE         1331
#                     FARMING          515
#                     GAME             247
#                     GARDEN          4725
#                     HEALTH          8232
#                     HISTORY         5403
#                     HOBBY             10
#                     HOLIDAY          400
#                     HOME            4962
#                     LANG INST        820
#                     LAW             1119
#                     LIFE            3382
#                     LIT             2707
#                     MYTH/FLK         219
#                     NATURE          3265
#                     PARTY            359
#                     PERS FIN        2830
#                     PET             1322
#                     PHILSOPH         673
#                     PSYCH           1496
#                     RELIGION        2551
#                     SCIENCE         1906
#                     SELFHELP        3340
#                     SOC SCI         2707
#                     SPIRIT          2093
#                     SPORT           1680
#                     TECH             246
#                     TRANSPRT         318
#                     TRAVEL          5896
#                     TRIBE            184
# Pacifica Sharp Park ART             7333
#                     BIO             7202
#                     BUSINESS        3193
#                     COLLECT          135
#                     COMPUTE         2170
#                     CONSUMER          40
#                     COOKING        12286
#                     CRAFT           5652
#                     EDUCATE         2484
#                     FARMING          317
#                     GAME             290
#                     GARDEN          5032
#                     GENEALGY          80
#                     HEALTH          9289
#                     HISTORY         5611
#                     HOBBY            104
#                     HOLIDAY          441
#                     HOME            5639
#                     LANG INST       1291
#                     LAW             1492
#                     LIFE            4515
#                     LIT             3839
#                     MYTH/FLK         203
#                     NATURE          2761
#                     PARTY            164
#                     PERS FIN        2569
#                     PET             1699
#                     PHILSOPH         520
#                     PSYCH           2067
#                     RELIGION        1813
#                     SCIENCE         2598
#                     SELFHELP        4420
#                     SOC SCI         2627
#                     SPIRIT          2641
#                     SPORT           1413
#                     TECH             533
#                     TRANSPRT         472
#                     TRAVEL          5630
#                     TRIBE            295
# Portola Valley      ART             2892
#                     BIO             4086
#                     BUSINESS        2072
#                     COLLECT           45
#                     COMPUTE          559
#                     CONSUMER          40
#                     COOKING         6791
#                     CRAFT           3316
#                     EDUCATE         1147
#                     FARMING          226
#                     GAME              96
#                     GARDEN          3106
#                     HEALTH          4846
#                     HISTORY         3688
#                     HOBBY             15
#                     HOLIDAY           62
#                     HOME            2899
#                     LANG INST        126
#                     LAW              424
#                     LIFE            2695
#                     LIT             1795
#                     NATURE          1268
#                     PARTY             31
#                     PERS FIN         476
#                     PET              936
#                     PHILSOPH         563
#                     PSYCH           1398
#                     RELIGION        1198
#                     SCIENCE         1574
#                     SELFHELP        3057
#                     SOC SCI         1547
#                     SPIRIT           747
#                     SPORT           1004
#                     TECH             301
#                     TRANSPRT          19
#                     TRAVEL          3235
#                     TRIBE             17
# San Carlos          ART             7035
#                     BIO            18305
#                     BUSINESS       11681
#                     COLLECT          363
#                     COMPUTE         3858
#                     CONSUMER          81
#                     COOKING        27978
#                     CRAFT           6767
#                     EDUCATE         6409
#                     FARMING          345
#                     GAME             680
#                     GARDEN          4586
#                     HEALTH         16473
#                     HISTORY         8248
#                     HOBBY            175
#                     HOLIDAY          432
#                     HOME            6413
#                     LANG INST       1046
#                     LAW             2654
#                     LIFE            8959
#                     LIT             5883
#                     MYTH/FLK          62
#                     NATURE          2598
#                     PARTY            269
#                     PERS FIN        4625
#                     PET             1380
#                     PHILSOPH        1410
#                     PSYCH           4714
#                     RELIGION        4062
#                     SCIENCE         4930
#                     SELFHELP       12177
#                     SOC SCI         6445
#                     SPIRIT          2610
#                     SPORT           2632
#                     TECH            1484
#                     TRANSPRT         270
#                     TRAVEL          7343
#                     TRIBE             53
# Woodside            ART             2648
#                     BIO             5030
#                     BUSINESS        1500
#                     COLLECT           69
#                     COMPUTE          405
#                     CONSUMER          17
#                     COOKING         6873
#                     CRAFT           2869
#                     EDUCATE          910
#                     FARMING          501
#                     GAME             138
#                     GARDEN          3215
#                     GENEALGY          29
#                     HEALTH          3521
#                     HISTORY         3706
#                     HOBBY            101
#                     HOLIDAY          496
#                     HOME            3367
#                     LANG INST        427
#                     LAW              709
#                     LIFE            3312
#                     LIT             1298
#                     MYTH/FLK         115
#                     NATURE          2029
#                     PARTY            271
#                     PERS FIN        1053
#                     PET             1580
#                     PHILSOPH         209
#                     PSYCH           1572
#                     RELIGION        1266
#                     SCIENCE         1426
#                     SELFHELP        3527
#                     SOC SCI         2121
#                     SPIRIT           607
#                     SPORT            902
#                     TECH              54
#                     TRANSPRT          63
#                     TRAVEL          4024
#                     TRIBE            120

# %%
 a=  smcl_data_removed_final.groupby(['BRANCH']).sum()

# %%
b = a.drop(['YTDCIRC', 'YTDCIRC', 'TOT CHKOUT', 'TOT RENEW', '# RENEWALS', 'LYRCIRC'], axis=1)

# %%
b
# Out:
#                      Total_cir
# BRANCH
# Atherton                 36770
# Belmont                 348896
# Bookmobile                 501
# Brisbane                 35218
# East Palo Alto           24603
# Foster City             482474
# Half Moon Bay            96988
# Millbrae                280109
# Pacifica Sanchez        101185
# Pacifica Sharp Park     110860
# Portola Valley           58297
# San Carlos              195435
# Woodside                 62080

# %%
c = b.plot.bar(use_index = True ,y='Total_cir')

# %%
url = 'https://datahub.smcgov.org/resource/pkmq-j36i.json'
import requests
import json
from pandas.io.json import json_normalize

# %%
response = requests.get(url).json()
print(json.dumps(response, indent = 4, sort_keys = False))
# Out:
# [
#     {
#         "city": "San Mateo County",
#         "total_population": "739837",
#         "median_age": "39",
#         "_0_9_years": "13",
#         "_10_19_years": "11",
#         "_20_29_years": "12",
#         "_30_39_years": "15",
#         "_40_49_years": "15",
#         "_50_59_years": "14",
#         "_60_69_years": "10",
#         "_7_79_years": "6",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.10",
#         "asian": "26",
#         "black": "2",
#         "latino": "25",
#         "pacific_islander": "1",
#         "white": "41",
#         "speaks_english_less_than_very_well": "19"
#     },
#     {
#         "city": "Atherton ",
#         "total_population": "7034",
#         "median_age": "49",
#         "_0_9_years": "10",
#         "_10_19_years": "17",
#         "_20_29_years": "7",
#         "_30_39_years": "7",
#         "_40_49_years": "11",
#         "_50_59_years": "16",
#         "_60_69_years": "16",
#         "_7_79_years": "10",
#         "_80_years": "7",
#         "american_indian_alaska_native": "0.00",
#         "asian": "12",
#         "black": "0",
#         "latino": "5",
#         "pacific_islander": "0",
#         "white": "79",
#         "speaks_english_less_than_very_well": "4"
#     },
#     {
#         "city": "Belmont ",
#         "total_population": "26503",
#         "median_age": "40",
#         "_0_9_years": "13",
#         "_10_19_years": "11",
#         "_20_29_years": "10",
#         "_30_39_years": "16",
#         "_40_49_years": "15",
#         "_50_59_years": "15",
#         "_60_69_years": "11",
#         "_7_79_years": "6",
#         "_80_years": "5",
#         "american_indian_alaska_native": "0.20",
#         "asian": "23",
#         "black": "2",
#         "latino": "13",
#         "pacific_islander": "0",
#         "white": "56",
#         "speaks_english_less_than_very_well": "10"
#     },
#     {
#         "city": "Brisbane ",
#         "total_population": "4421",
#         "median_age": "44",
#         "_0_9_years": "11",
#         "_10_19_years": "8",
#         "_20_29_years": "7",
#         "_30_39_years": "18",
#         "_40_49_years": "15",
#         "_50_59_years": "19",
#         "_60_69_years": "12",
#         "_7_79_years": "5",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.40",
#         "asian": "32",
#         "black": "2",
#         "latino": "21",
#         "pacific_islander": "0",
#         "white": "42",
#         "speaks_english_less_than_very_well": "10"
#     },
#     {
#         "city": "Burlingame ",
#         "total_population": "29618",
#         "median_age": "40",
#         "_0_9_years": "15",
#         "_10_19_years": "10",
#         "_20_29_years": "10",
#         "_30_39_years": "15",
#         "_40_49_years": "19",
#         "_50_59_years": "13",
#         "_60_69_years": "9",
#         "_7_79_years": "5",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.20",
#         "asian": "21",
#         "black": "1",
#         "latino": "13",
#         "pacific_islander": "0",
#         "white": "59",
#         "speaks_english_less_than_very_well": "12"
#     },
#     {
#         "city": "Colma ",
#         "total_population": "1837",
#         "median_age": "30",
#         "_0_9_years": "13",
#         "_10_19_years": "11",
#         "_20_29_years": "25",
#         "_30_39_years": "15",
#         "_40_49_years": "8",
#         "_50_59_years": "15",
#         "_60_69_years": "6",
#         "_7_79_years": "5",
#         "_80_years": "1",
#         "american_indian_alaska_native": "0.00",
#         "asian": "32",
#         "black": "2",
#         "latino": "52",
#         "pacific_islander": "0",
#         "white": "9",
#         "speaks_english_less_than_very_well": "31"
#     },
#     {
#         "city": "Daly City ",
#         "total_population": "103897",
#         "median_age": "38",
#         "_0_9_years": "11",
#         "_10_19_years": "11",
#         "_20_29_years": "16",
#         "_30_39_years": "15",
#         "_40_49_years": "13",
#         "_50_59_years": "14",
#         "_60_69_years": "10",
#         "_7_79_years": "6",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.20",
#         "asian": "57",
#         "black": "3",
#         "latino": "23",
#         "pacific_islander": "0",
#         "white": "13",
#         "speaks_english_less_than_very_well": "30"
#     },
#     {
#         "city": "East Palo Alto ",
#         "total_population": "28920",
#         "median_age": "29",
#         "_0_9_years": "17",
#         "_10_19_years": "16",
#         "_20_29_years": "20",
#         "_30_39_years": "16",
#         "_40_49_years": "13",
#         "_50_59_years": "10",
#         "_60_69_years": "5",
#         "_7_79_years": "3",
#         "_80_years": "1",
#         "american_indian_alaska_native": "0.00",
#         "asian": "3",
#         "black": "14",
#         "latino": "62",
#         "pacific_islander": "12",
#         "white": "7",
#         "speaks_english_less_than_very_well": "35"
#     },
#     {
#         "city": "Foster City ",
#         "total_population": "31809",
#         "median_age": "41",
#         "_0_9_years": "13",
#         "_10_19_years": "10",
#         "_20_29_years": "9",
#         "_30_39_years": "17",
#         "_40_49_years": "16",
#         "_50_59_years": "13",
#         "_60_69_years": "13",
#         "_7_79_years": "6",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.10",
#         "asian": "46",
#         "black": "2",
#         "latino": "6",
#         "pacific_islander": "0",
#         "white": "42",
#         "speaks_english_less_than_very_well": "19"
#     },
#     {
#         "city": "Half Moon Bay ",
#         "total_population": "11803",
#         "median_age": "45",
#         "_0_9_years": "10",
#         "_10_19_years": "12",
#         "_20_29_years": "12",
#         "_30_39_years": "11",
#         "_40_49_years": "12",
#         "_50_59_years": "16",
#         "_60_69_years": "15",
#         "_7_79_years": "8",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.00",
#         "asian": "5",
#         "black": "2",
#         "latino": "31",
#         "pacific_islander": "0",
#         "white": "61",
#         "speaks_english_less_than_very_well": "17"
#     },
#     {
#         "city": "Hillsborough ",
#         "total_population": "11148",
#         "median_age": "46",
#         "_0_9_years": "14",
#         "_10_19_years": "15",
#         "_20_29_years": "5",
#         "_30_39_years": "6",
#         "_40_49_years": "16",
#         "_50_59_years": "16",
#         "_60_69_years": "15",
#         "_7_79_years": "8",
#         "_80_years": "5",
#         "american_indian_alaska_native": "0.10",
#         "asian": "27",
#         "black": "1",
#         "latino": "5",
#         "pacific_islander": "0",
#         "white": "63",
#         "speaks_english_less_than_very_well": "7"
#     },
#     {
#         "city": "Menlo Park",
#         "total_population": "32792",
#         "median_age": "38",
#         "_0_9_years": "16",
#         "_10_19_years": "10",
#         "_20_29_years": "11",
#         "_30_39_years": "16",
#         "_40_49_years": "15",
#         "_50_59_years": "13",
#         "_60_69_years": "9",
#         "_7_79_years": "6",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.20",
#         "asian": "11",
#         "black": "5",
#         "latino": "16",
#         "pacific_islander": "2",
#         "white": "63",
#         "speaks_english_less_than_very_well": "10"
#     },
#     {
#         "city": "Millbrae ",
#         "total_population": "22177",
#         "median_age": "45",
#         "_0_9_years": "10",
#         "_10_19_years": "12",
#         "_20_29_years": "11",
#         "_30_39_years": "12",
#         "_40_49_years": "13",
#         "_50_59_years": "17",
#         "_60_69_years": "12",
#         "_7_79_years": "7",
#         "_80_years": "7",
#         "american_indian_alaska_native": "0.20",
#         "asian": "43",
#         "black": "1",
#         "latino": "15",
#         "pacific_islander": "1",
#         "white": "38",
#         "speaks_english_less_than_very_well": "19"
#     },
#     {
#         "city": "Pacifica ",
#         "total_population": "38283",
#         "median_age": "42",
#         "_0_9_years": "11",
#         "_10_19_years": "12",
#         "_20_29_years": "11",
#         "_30_39_years": "13",
#         "_40_49_years": "17",
#         "_50_59_years": "16",
#         "_60_69_years": "12",
#         "_7_79_years": "5",
#         "_80_years": "3",
#         "american_indian_alaska_native": "0.20",
#         "asian": "19",
#         "black": "3",
#         "latino": "18",
#         "pacific_islander": "1",
#         "white": "54",
#         "speaks_english_less_than_very_well": "7"
#     },
#     {
#         "city": "Portola Valley ",
#         "total_population": "4478",
#         "median_age": "55",
#         "_0_9_years": "8",
#         "_10_19_years": "12",
#         "_20_29_years": "3",
#         "_30_39_years": "9",
#         "_40_49_years": "10",
#         "_50_59_years": "18",
#         "_60_69_years": "19",
#         "_7_79_years": "11",
#         "_80_years": "11",
#         "american_indian_alaska_native": "0.00",
#         "asian": "8",
#         "black": "0",
#         "latino": "3",
#         "pacific_islander": "0",
#         "white": "86",
#         "speaks_english_less_than_very_well": "3"
#     },
#     {
#         "city": "Redwood City ",
#         "total_population": "79736",
#         "median_age": "37",
#         "_0_9_years": "15",
#         "_10_19_years": "12",
#         "_20_29_years": "12",
#         "_30_39_years": "16",
#         "_40_49_years": "17",
#         "_50_59_years": "13",
#         "_60_69_years": "8",
#         "_7_79_years": "4",
#         "_80_years": "3",
#         "american_indian_alaska_native": "0.20",
#         "asian": "12",
#         "black": "2",
#         "latino": "40",
#         "pacific_islander": "0",
#         "white": "42",
#         "speaks_english_less_than_very_well": "21"
#     },
#     {
#         "city": "San Bruno ",
#         "total_population": "42090",
#         "median_age": "39",
#         "_0_9_years": "12",
#         "_10_19_years": "10",
#         "_20_29_years": "15",
#         "_30_39_years": "15",
#         "_40_49_years": "15",
#         "_50_59_years": "15",
#         "_60_69_years": "10",
#         "_7_79_years": "5",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.20",
#         "asian": "26",
#         "black": "2",
#         "latino": "30",
#         "pacific_islander": "3",
#         "white": "34",
#         "speaks_english_less_than_very_well": "18"
#     },
#     {
#         "city": "San Carlos ",
#         "total_population": "29166",
#         "median_age": "43",
#         "_0_9_years": "14",
#         "_10_19_years": "11",
#         "_20_29_years": "8",
#         "_30_39_years": "13",
#         "_40_49_years": "17",
#         "_50_59_years": "16",
#         "_60_69_years": "10",
#         "_7_79_years": "6",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.00",
#         "asian": "12",
#         "black": "1",
#         "latino": "11",
#         "pacific_islander": "1",
#         "white": "72",
#         "speaks_english_less_than_very_well": "5"
#     },
#     {
#         "city": "San Mateo ",
#         "total_population": "100114",
#         "median_age": "39",
#         "_0_9_years": "13",
#         "_10_19_years": "10",
#         "_20_29_years": "13",
#         "_30_39_years": "16",
#         "_40_49_years": "15",
#         "_50_59_years": "14",
#         "_60_69_years": "9",
#         "_7_79_years": "6",
#         "_80_years": "5",
#         "american_indian_alaska_native": "0.10",
#         "asian": "19",
#         "black": "2",
#         "latino": "26",
#         "pacific_islander": "2",
#         "white": "47",
#         "speaks_english_less_than_very_well": "19"
#     },
#     {
#         "city": "South San Francisco",
#         "total_population": "65537",
#         "median_age": "39",
#         "_0_9_years": "12",
#         "_10_19_years": "11",
#         "_20_29_years": "13",
#         "_30_39_years": "16",
#         "_40_49_years": "14",
#         "_50_59_years": "14",
#         "_60_69_years": "10",
#         "_7_79_years": "6",
#         "_80_years": "4",
#         "american_indian_alaska_native": "0.10",
#         "asian": "38",
#         "black": "2",
#         "latino": "34",
#         "pacific_islander": "2",
#         "white": "20",
#         "speaks_english_less_than_very_well": "24"
#     },
#     {
#         "city": "Woodside",
#         "total_population": "5427",
#         "median_age": "50",
#         "_0_9_years": "9",
#         "_10_19_years": "17",
#         "_20_29_years": "4",
#         "_30_39_years": "6",
#         "_40_49_years": "15",
#         "_50_59_years": "20",
#         "_60_69_years": "13",
#         "_7_79_years": "9",
#         "_80_years": "7",
#         "american_indian_alaska_native": "0.00",
#         "asian": "5",
#         "black": "0",
#         "latino": "4",
#         "pacific_islander": "0",
#         "white": "88",
#         "speaks_english_less_than_very_well": "3"
#     }
# ]

# %%
len(response)
# Out:
# 21

# %%
cencus_data = json_normalize(response)
cencus_data.head()
# Out:
#                city total_population median_age _0_9_years _10_19_years  \
# 0  San Mateo County           739837         39         13           11
# 1         Atherton              7034         49         10           17
# 2          Belmont             26503         40         13           11
# 3         Brisbane              4421         44         11            8
# 4       Burlingame             29618         40         15           10
#
#   _20_29_years _30_39_years _40_49_years _50_59_years _60_69_years  \
# 0           12           15           15           14           10
# 1            7            7           11           16           16
# 2           10           16           15           15           11
# 3            7           18           15           19           12
# 4           10           15           19           13            9
#
#   _7_79_years _80_years american_indian_alaska_native asian black latino  \
# 0           6         4                          0.10    26     2     25
# 1          10         7                          0.00    12     0      5
# 2           6         5                          0.20    23     2     13
# 3           5         4                          0.40    32     2     21
# 4           5         4                          0.20    21     1     13
#
#   pacific_islander white speaks_english_less_than_very_well
# 0                1    41                                 19
# 1                0    79                                  4
# 2                0    56                                 10
# 3                0    42                                 10
# 4                0    59                                 12

# %%
pop_data = cencus_data[['city', 'total_population']]
pop_data['city'] = pop_data['city'].str.strip()
pop_data
# Out:
# C:\Users\onlyd\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    city total_population
# 0      San Mateo County           739837
# 1              Atherton             7034
# 2               Belmont            26503
# 3              Brisbane             4421
# 4            Burlingame            29618
# 5                 Colma             1837
# 6             Daly City           103897
# 7        East Palo Alto            28920
# 8           Foster City            31809
# 9         Half Moon Bay            11803
# 10         Hillsborough            11148
# 11           Menlo Park            32792
# 12             Millbrae            22177
# 13             Pacifica            38283
# 14       Portola Valley             4478
# 15         Redwood City            79736
# 16            San Bruno            42090
# 17           San Carlos            29166
# 18            San Mateo           100114
# 19  South San Francisco            65537
# 20             Woodside             5427

# %%
cir_data = b.reset_index(drop = False)
cir_data = cir_data.rename(columns = {"BRANCH" : "city"})
pacifica = pd.DataFrame({'city' : 'Pacifica', 'Total_cir' : [cir_data.loc[8, 'Total_cir'] + cir_data.loc[9, 'Total_cir']]})
cir_data = cir_data.append(pacifica).reset_index(drop = True)
cir_data = cir_data.drop([8, 9, 2]).reset_index(drop = True)
cir_data
# Out:
#               city  Total_cir
# 0         Atherton      36770
# 1          Belmont     348896
# 2         Brisbane      35218
# 3   East Palo Alto      24603
# 4      Foster City     482474
# 5    Half Moon Bay      96988
# 6         Millbrae     280109
# 7   Portola Valley      58297
# 8       San Carlos     195435
# 9         Woodside      62080
# 10        Pacifica     212045

# %%
pop_cir_data = pd.merge(pop_data, cir_data, how = 'right', on = 'city')
pop_cir_data = pop_cir_data.set_index('city')
pop_cir_data
# Out:
#                total_population  Total_cir
# city
# Atherton                   7034      36770
# Belmont                   26503     348896
# Brisbane                   4421      35218
# East Palo Alto            28920      24603
# Foster City               31809     482474
# Half Moon Bay             11803      96988
# Millbrae                  22177     280109
# Pacifica                  38283     212045
# Portola Valley             4478      58297
# San Carlos                29166     195435
# Woodside                   5427      62080

# %%
pop_cir_data['Total_cir'] = pop_cir_data.Total_cir.astype(float)
#pop_cir_data['Total_cir'] = pop_cir_data['Total_cir'].sort_values(ascending=True)
pop_cir_data['total_population'] = pop_cir_data.total_population.astype(float)

# %%
pop_cir_data['total_population'].sort_values()
# Out:
# city
# Brisbane           4421.0
# Portola Valley     4478.0
# Woodside           5427.0
# Atherton           7034.0
# Half Moon Bay     11803.0
# Millbrae          22177.0
# Belmont           26503.0
# East Palo Alto    28920.0
# San Carlos        29166.0
# Foster City       31809.0
# Pacifica          38283.0
# Name: total_population, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figsize=(20,10)
plt.scatter(pop_cir_data['total_population'].sort_values(), pop_cir_data['Total_cir'].sort_values())
plt.ylabel('Library Circulation')
plt.xlabel('City Population')
# Out:
# Text(0.5, 0, 'City Population')

# %%
from scipy.stats import linregress

(slope, intercept, rvalue, pvalue, stderr) = linregress(pop_cir_data['total_population'], pop_cir_data['Total_cir'])
regress_values = pop_cir_data['total_population'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(pop_cir_data['total_population'].sort_values(), pop_cir_data['Total_cir'].sort_values())
plt.plot(pop_cir_data['total_population'],regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
# Out:
# Text(6, 10, 'y = 7.78x + 18118.62')

# %%
import scipy.stats as stats
stats.ttest_ind(pop_cir_data['total_population'], pop_cir_data['Total_cir'], equal_var=False)
# Out:
# Ttest_indResult(statistic=-3.2113329008176406, pvalue=0.00915252607912857)

# %%
demo_data = cencus_data[['city', 'american_indian_alaska_native', 'asian', 'black', 'latino', 'pacific_islander', 'white']]
demo_data['city'] = pop_data['city'].str.strip()
demo_data
# Out:
# C:\Users\onlyd\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    city american_indian_alaska_native asian black latino  \
# 0      San Mateo County                          0.10    26     2     25
# 1              Atherton                          0.00    12     0      5
# 2               Belmont                          0.20    23     2     13
# 3              Brisbane                          0.40    32     2     21
# 4            Burlingame                          0.20    21     1     13
# 5                 Colma                          0.00    32     2     52
# 6             Daly City                          0.20    57     3     23
# 7        East Palo Alto                          0.00     3    14     62
# 8           Foster City                          0.10    46     2      6
# 9         Half Moon Bay                          0.00     5     2     31
# 10         Hillsborough                          0.10    27     1      5
# 11           Menlo Park                          0.20    11     5     16
# 12             Millbrae                          0.20    43     1     15
# 13             Pacifica                          0.20    19     3     18
# 14       Portola Valley                          0.00     8     0      3
# 15         Redwood City                          0.20    12     2     40
# 16            San Bruno                          0.20    26     2     30
# 17           San Carlos                          0.00    12     1     11
# 18            San Mateo                          0.10    19     2     26
# 19  South San Francisco                          0.10    38     2     34
# 20             Woodside                          0.00     5     0      4
#
#    pacific_islander white
# 0                 1    41
# 1                 0    79
# 2                 0    56
# 3                 0    42
# 4                 0    59
# 5                 0     9
# 6                 0    13
# 7                12     7
# 8                 0    42
# 9                 0    61
# 10                0    63
# 11                2    63
# 12                1    38
# 13                1    54
# 14                0    86
# 15                0    42
# 16                3    34
# 17                1    72
# 18                2    47
# 19                2    20
# 20                0    88

# %%
demo_cir_data = pd.merge(demo_data, cir_data, how = 'right', on = 'city')
demo_cir_data = demo_cir_data.set_index('city')
demo_cir_data
# Out:
#                american_indian_alaska_native asian black latino  \
# city
# Atherton                                0.00    12     0      5
# Belmont                                 0.20    23     2     13
# Brisbane                                0.40    32     2     21
# East Palo Alto                          0.00     3    14     62
# Foster City                             0.10    46     2      6
# Half Moon Bay                           0.00     5     2     31
# Millbrae                                0.20    43     1     15
# Pacifica                                0.20    19     3     18
# Portola Valley                          0.00     8     0      3
# San Carlos                              0.00    12     1     11
# Woodside                                0.00     5     0      4
#
#                pacific_islander white  Total_cir
# city
# Atherton                      0    79      36770
# Belmont                       0    56     348896
# Brisbane                      0    42      35218
# East Palo Alto               12     7      24603
# Foster City                   0    42     482474
# Half Moon Bay                 0    61      96988
# Millbrae                      1    38     280109
# Pacifica                      1    54     212045
# Portola Valley                0    86      58297
# San Carlos                    1    72     195435
# Woodside                      0    88      62080

# %%
demo_cir_data["asian"] = demo_cir_data.asian.astype(float)
demo_cir_data["white"] = demo_cir_data.white.astype(float)
demo_cir_data["black"] = demo_cir_data.black.astype(float)
demo_cir_data["latino"] = demo_cir_data.latino.astype(float)
demo_cir_data["american_indian_alaska_native"] = demo_cir_data.american_indian_alaska_native.astype(float)

#demo_cir_data['asian'] = demo_cir_data['asian'].sort_values(ascending=True)
#demo_cir_data['asian'].sort_values(ascending=True)

# %%
demo_cir_data['asian'].sort_values()
# Out:
# city
# East Palo Alto     3.0
# Half Moon Bay      5.0
# Woodside           5.0
# Portola Valley     8.0
# Atherton          12.0
# San Carlos        12.0
# Pacifica          19.0
# Belmont           23.0
# Brisbane          32.0
# Millbrae          43.0
# Foster City       46.0
# Name: asian, dtype: float64

# %%
plt.figsize=(20,10)
plt.scatter(demo_cir_data['asian'].sort_values(), pop_cir_data['Total_cir'].sort_values())
plt.ylabel('Library Circulation')
plt.xlabel('% of Asian Population')
# Out:
# Text(0.5, 0, '% of Asian Population')

# %%
age_data = cencus_data[['city', 'median_age', '_0_9_years', '_10_19_years', '_20_29_years', '_30_39_years', '_40_49_years', '_50_59_years', '_60_69_years', '_7_79_years', '_80_years']]
age_data['city'] = pop_data['city'].str.strip()
age_data
# Out:
# C:\Users\onlyd\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                    city median_age _0_9_years _10_19_years _20_29_years  \
# 0      San Mateo County         39         13           11           12
# 1              Atherton         49         10           17            7
# 2               Belmont         40         13           11           10
# 3              Brisbane         44         11            8            7
# 4            Burlingame         40         15           10           10
# 5                 Colma         30         13           11           25
# 6             Daly City         38         11           11           16
# 7        East Palo Alto         29         17           16           20
# 8           Foster City         41         13           10            9
# 9         Half Moon Bay         45         10           12           12
# 10         Hillsborough         46         14           15            5
# 11           Menlo Park         38         16           10           11
# 12             Millbrae         45         10           12           11
# 13             Pacifica         42         11           12           11
# 14       Portola Valley         55          8           12            3
# 15         Redwood City         37         15           12           12
# 16            San Bruno         39         12           10           15
# 17           San Carlos         43         14           11            8
# 18            San Mateo         39         13           10           13
# 19  South San Francisco         39         12           11           13
# 20             Woodside         50          9           17            4
#
#    _30_39_years _40_49_years _50_59_years _60_69_years _7_79_years _80_years
# 0            15           15           14           10           6         4
# 1             7           11           16           16          10         7
# 2            16           15           15           11           6         5
# 3            18           15           19           12           5         4
# 4            15           19           13            9           5         4
# 5            15            8           15            6           5         1
# 6            15           13           14           10           6         4
# 7            16           13           10            5           3         1
# 8            17           16           13           13           6         4
# 9            11           12           16           15           8         4
# 10            6           16           16           15           8         5
# 11           16           15           13            9           6         4
# 12           12           13           17           12           7         7
# 13           13           17           16           12           5         3
# 14            9           10           18           19          11        11
# 15           16           17           13            8           4         3
# 16           15           15           15           10           5         4
# 17           13           17           16           10           6         4
# 18           16           15           14            9           6         5
# 19           16           14           14           10           6         4
# 20            6           15           20           13           9         7

# %%
age_cir_data = pd.merge(age_data, cir_data, how = 'right', on = 'city')
age_cir_data = age_cir_data.set_index('city')
age_cir_data
# Out:
#                median_age _0_9_years _10_19_years _20_29_years _30_39_years  \
# city
# Atherton               49         10           17            7            7
# Belmont                40         13           11           10           16
# Brisbane               44         11            8            7           18
# East Palo Alto         29         17           16           20           16
# Foster City            41         13           10            9           17
# Half Moon Bay          45         10           12           12           11
# Millbrae               45         10           12           11           12
# Pacifica               42         11           12           11           13
# Portola Valley         55          8           12            3            9
# San Carlos             43         14           11            8           13
# Woodside               50          9           17            4            6
#
#                _40_49_years _50_59_years _60_69_years _7_79_years _80_years  \
# city
# Atherton                 11           16           16          10         7
# Belmont                  15           15           11           6         5
# Brisbane                 15           19           12           5         4
# East Palo Alto           13           10            5           3         1
# Foster City              16           13           13           6         4
# Half Moon Bay            12           16           15           8         4
# Millbrae                 13           17           12           7         7
# Pacifica                 17           16           12           5         3
# Portola Valley           10           18           19          11        11
# San Carlos               17           16           10           6         4
# Woodside                 15           20           13           9         7
#
#                 Total_cir
# city
# Atherton            36770
# Belmont            348896
# Brisbane            35218
# East Palo Alto      24603
# Foster City        482474
# Half Moon Bay       96988
# Millbrae           280109
# Pacifica           212045
# Portola Valley      58297
# San Carlos         195435
# Woodside            62080

# %%
age_cir_data["Total_cir"] = age_cir_data.Total_cir.astype(float)
age_cir_data["median_age"] = age_cir_data.median_age.astype(float)

# %%
plt.figsize=(20,10)
plt.scatter(age_cir_data['median_age'].sort_values(), pop_cir_data['Total_cir'].sort_values())
plt.ylabel('Total Circulation')
plt.xlabel('Median Age')
# Out:
# Text(0.5, 0, 'Median Age')

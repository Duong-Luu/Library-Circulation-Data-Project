# %%
import pandas as pd
import re as re

# %%
smcl_data = pd.read_csv("SMCL_ANF_Items.csv")
smcl_data
# Out:
#       LOCATION BRANCH MATERIAL       BARCODE RECORD #(ITEM)    CREATED(ITEM)  \
# 0        1vanf     1v      anf  3.904100e+13      i10000471   7/18/2005 8:45
# 1        1zanf     1z      anf  3.904100e+13      i10001098   7/18/2005 8:45
# 2        1fanf     1f      anf  3.904100e+13      i10001475   7/18/2005 8:45
# 3        1manf     1m      anf  3.904100e+13      i10001517   7/18/2005 8:45
# 4        1eanf     1e      anf  3.904100e+13      i10010816   7/18/2005 8:47
# ...        ...    ...      ...           ...            ...              ...
# 70785    1hanf     1h      anf  3.904110e+13      i80124422  3/16/2020 10:47
# 70786    1manf     1m      anf  3.904110e+13      i80124434  3/16/2020 10:47
# 70787    1sanf     1s      anf  3.904110e+13      i80124446  3/16/2020 10:47
# 70788    1eanf     1e      anf  3.904110e+13      i80124458  3/16/2020 10:47
# 70789    1eanf     1e      anf  3.904110e+13      i8012494x  3/16/2020 11:23
#
#       RECORD #(BIBLIO)   CREATED(BIBLIO)  I TYPE MAT TYPE  ...  # RENEWALS  \
# 0            b10000203    7/18/2005 8:45      10      a    ...           0
# 1            b10000276    7/18/2005 8:45      10      a    ...           0
# 2            b1000032x    7/18/2005 8:45      10      a    ...           0
# 3            b1000032x    7/18/2005 8:45      10      a    ...           0
# 4            b10002364    7/18/2005 8:47      10      a    ...           0
# ...                ...               ...     ...      ...  ...         ...
# 70785        b2849555x  11/12/2019 14:54      10      a    ...           0
# 70786        b2849555x  11/12/2019 14:54      10      a    ...           0
# 70787        b2849555x  11/12/2019 14:54      10      a    ...           0
# 70788        b2849555x  11/12/2019 14:54      10      a    ...           0
# 70789        b26571018  11/21/2018 12:27      10      a    ...           0
#
#        STATUS  DUE DATE          LOUTDATE           LCHKIN         CALL #  \
# 0         m      -  -     4/28/2016 15:35  5/24/2016 11:00  NATURE MAMMAL
# 1         -      -  -     4/18/2018 17:17  5/14/2018 10:40  NATURE MARINE
# 2         -      -  -    11/24/2019 16:41  1/10/2020 10:47    NATURE BIRD
# 3         -      -  -     7/12/2018 15:36  7/14/2018 11:13    NATURE BIRD
# 4         m      -  -      6/8/2016 16:57  8/17/2016 17:01   COOKING INTL
# ...       ...       ...               ...              ...            ...
# 70785     t      -  -              -  -             -  -      ART ANIMATE
# 70786     t      -  -              -  -             -  -      ART ANIMATE
# 70787     t      -  -              -  -             -  -      ART ANIMATE
# 70788     t      -  -              -  -             -  -      ART ANIMATE
# 70789     t      -  -              -  -             -  -      ART PERFORM
#
#                        OTHER CALL                            245|a  \
# 0      599 E 1998;"NATURE MAMMAL"        Encyclopedia of mammals /
# 1                      597 E 1998         Encyclopedia of fishes /
# 2                    598.2 E 1998          Encyclopedia of birds /
# 3                    598.2 E 1998          Encyclopedia of birds /
# 4                      641.5972 G  Caribbean and African cooking /
# ...                           ...                              ...
# 70785                         NaN                        Blender /
# 70786                         NaN                        Blender /
# 70787                         NaN                        Blender /
# 70788                         NaN                        Blender /
# 70789                         NaN         Showtime at the Apollo :
#
#                      100|a 008 Date One
# 0                      NaN         1998
# 1                      NaN         1998
# 2                      NaN         1998
# 3                      NaN         1998
# 4         Grant, Rosamund.         1998
# ...                    ...          ...
# 70785  Van Gumster, Jason,         2020
# 70786  Van Gumster, Jason,         2020
# 70787  Van Gumster, Jason,         2020
# 70788  Van Gumster, Jason,         2020
# 70789            Fox, Ted,         2018
#
# [70790 rows x 24 columns]

# %%
#Renamed the columns for column V, W, X

smcl_data2 = smcl_data.rename(columns={'245|a': 'Book Title','100|a': 'Author',
                                      '008 Date One': 'Published Date'})
#dropped columns

smcl_data_clean = smcl_data2.drop(['LOCATION', 'BARCODE', 'RECORD #(ITEM)',
                 'I TYPE', 'MAT TYPE', 'OTHER CALL'], axis=1)
smcl_data_clean
# Out:
#       BRANCH MATERIAL    CREATED(ITEM) RECORD #(BIBLIO)   CREATED(BIBLIO)  \
# 0         1v      anf   7/18/2005 8:45        b10000203    7/18/2005 8:45
# 1         1z      anf   7/18/2005 8:45        b10000276    7/18/2005 8:45
# 2         1f      anf   7/18/2005 8:45        b1000032x    7/18/2005 8:45
# 3         1m      anf   7/18/2005 8:45        b1000032x    7/18/2005 8:45
# 4         1e      anf   7/18/2005 8:47        b10002364    7/18/2005 8:47
# ...      ...      ...              ...              ...               ...
# 70785     1h      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70786     1m      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70787     1s      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70788     1e      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70789     1e      anf  3/16/2020 11:23        b26571018  11/21/2018 12:27
#
#        YTDCIRC  LYRCIRC  TOT CHKOUT  TOT RENEW  # RENEWALS STATUS  DUE DATE  \
# 0            0        0          15          6           0    m      -  -
# 1            0        0          30         11           0    -      -  -
# 2            2        3          40         23           0    -      -  -
# 3            0        0          17          9           0    -      -  -
# 4            0        0           8          8           0    m      -  -
# ...        ...      ...         ...        ...         ...    ...       ...
# 70785        0        0           0          0           0    t      -  -
# 70786        0        0           0          0           0    t      -  -
# 70787        0        0           0          0           0    t      -  -
# 70788        0        0           0          0           0    t      -  -
# 70789        0        0           0          0           0    t      -  -
#
#                LOUTDATE           LCHKIN         CALL #  \
# 0       4/28/2016 15:35  5/24/2016 11:00  NATURE MAMMAL
# 1       4/18/2018 17:17  5/14/2018 10:40  NATURE MARINE
# 2      11/24/2019 16:41  1/10/2020 10:47    NATURE BIRD
# 3       7/12/2018 15:36  7/14/2018 11:13    NATURE BIRD
# 4        6/8/2016 16:57  8/17/2016 17:01   COOKING INTL
# ...                 ...              ...            ...
# 70785            -  -             -  -      ART ANIMATE
# 70786            -  -             -  -      ART ANIMATE
# 70787            -  -             -  -      ART ANIMATE
# 70788            -  -             -  -      ART ANIMATE
# 70789            -  -             -  -      ART PERFORM
#
#                             Book Title               Author Published Date
# 0            Encyclopedia of mammals /                  NaN           1998
# 1             Encyclopedia of fishes /                  NaN           1998
# 2              Encyclopedia of birds /                  NaN           1998
# 3              Encyclopedia of birds /                  NaN           1998
# 4      Caribbean and African cooking /     Grant, Rosamund.           1998
# ...                                ...                  ...            ...
# 70785                        Blender /  Van Gumster, Jason,           2020
# 70786                        Blender /  Van Gumster, Jason,           2020
# 70787                        Blender /  Van Gumster, Jason,           2020
# 70788                        Blender /  Van Gumster, Jason,           2020
# 70789         Showtime at the Apollo :            Fox, Ted,           2018
#
# [70790 rows x 18 columns]

# %%
#looking for values to combine in Call # field
smcl_data_clean["CALL #"].value_counts()

#cleaning up and only using initial categorey 
smcl_data_clean["CALL #"] = smcl_data_clean["CALL #"].str.split(" ", 1, expand=True)
smcl_data_clean
# Out:
#       BRANCH MATERIAL    CREATED(ITEM) RECORD #(BIBLIO)   CREATED(BIBLIO)  \
# 0         1v      anf   7/18/2005 8:45        b10000203    7/18/2005 8:45
# 1         1z      anf   7/18/2005 8:45        b10000276    7/18/2005 8:45
# 2         1f      anf   7/18/2005 8:45        b1000032x    7/18/2005 8:45
# 3         1m      anf   7/18/2005 8:45        b1000032x    7/18/2005 8:45
# 4         1e      anf   7/18/2005 8:47        b10002364    7/18/2005 8:47
# ...      ...      ...              ...              ...               ...
# 70785     1h      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70786     1m      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70787     1s      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70788     1e      anf  3/16/2020 10:47        b2849555x  11/12/2019 14:54
# 70789     1e      anf  3/16/2020 11:23        b26571018  11/21/2018 12:27
#
#        YTDCIRC  LYRCIRC  TOT CHKOUT  TOT RENEW  # RENEWALS STATUS  DUE DATE  \
# 0            0        0          15          6           0    m      -  -
# 1            0        0          30         11           0    -      -  -
# 2            2        3          40         23           0    -      -  -
# 3            0        0          17          9           0    -      -  -
# 4            0        0           8          8           0    m      -  -
# ...        ...      ...         ...        ...         ...    ...       ...
# 70785        0        0           0          0           0    t      -  -
# 70786        0        0           0          0           0    t      -  -
# 70787        0        0           0          0           0    t      -  -
# 70788        0        0           0          0           0    t      -  -
# 70789        0        0           0          0           0    t      -  -
#
#                LOUTDATE           LCHKIN   CALL #  \
# 0       4/28/2016 15:35  5/24/2016 11:00   NATURE
# 1       4/18/2018 17:17  5/14/2018 10:40   NATURE
# 2      11/24/2019 16:41  1/10/2020 10:47   NATURE
# 3       7/12/2018 15:36  7/14/2018 11:13   NATURE
# 4        6/8/2016 16:57  8/17/2016 17:01  COOKING
# ...                 ...              ...      ...
# 70785            -  -             -  -        ART
# 70786            -  -             -  -        ART
# 70787            -  -             -  -        ART
# 70788            -  -             -  -        ART
# 70789            -  -             -  -        ART
#
#                             Book Title               Author Published Date
# 0            Encyclopedia of mammals /                  NaN           1998
# 1             Encyclopedia of fishes /                  NaN           1998
# 2              Encyclopedia of birds /                  NaN           1998
# 3              Encyclopedia of birds /                  NaN           1998
# 4      Caribbean and African cooking /     Grant, Rosamund.           1998
# ...                                ...                  ...            ...
# 70785                        Blender /  Van Gumster, Jason,           2020
# 70786                        Blender /  Van Gumster, Jason,           2020
# 70787                        Blender /  Van Gumster, Jason,           2020
# 70788                        Blender /  Van Gumster, Jason,           2020
# 70789         Showtime at the Apollo :            Fox, Ted,           2018
#
# [70790 rows x 18 columns]

# %%
smcl_data_clean["CALL #"].value_counts()
# Out:
# BIO        6789
# COOKING    5231
# HISTORY    4966
# HEALTH     4575
# TRAVEL     4540
#            ...
# M-VAN         1
# TOWN          1
# F-URB         1
# F-MUR         1
# SF-OWE        1
# Name: CALL #, Length: 254, dtype: int64
